# %% [markdown]
# # 🔢 Notebook 04: Embeddings and Vector Representations
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ## 🎯 Objectives
# 1. Understand what embeddings are
# 2. Use OpenAI Embeddings
# 3. Use Google Gemini Embeddings
# 4. Compare embedding models
# 5. Calculate similarity between vectors

# %%
from dotenv import load_dotenv
import os
load_dotenv()
print("✅ Setup complete")
# Out:
# ✅ Setup complete

# %% [markdown]
# ## 1. What are Embeddings? 🤔
#
# ### 🔰 BEGINNER
#
# **Embeddings** convert text into numbers (vectors) that capture meaning.
#
# Think of it like a GPS coordinate:
# - "dog" → [0.2, 0.8, 0.1, ...] (1536 numbers)
# - "cat" → [0.3, 0.7, 0.2, ...] (close to "dog"!)
# - "car" → [0.9, 0.1, 0.8, ...] (far from "dog")
#
# Similar meanings = Similar vectors!

# %% [markdown]
# ## 2. OpenAI Embeddings

# %%
# from langchain_openai import OpenAIEmbeddings
from langchain_ollama import OllamaEmbeddings

# Initialize
# embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
embeddings = OllamaEmbeddings(model="embeddinggemma:latest")

# Create embedding for a query
query = "What is machine learning?"
query_vector = embeddings.embed_query(query)

print(f"Query: {query}")
print(f"Vector dimensions: {len(query_vector)}")
print(f"First 5 values: {query_vector[:5]}")

# Embed multiple documents
docs = [
    "Machine learning is a subset of AI",
    "Deep learning uses neural networks",
    "The weather is sunny today"
]

doc_vectors = embeddings.embed_documents(docs)
print(f"\nEmbedded {len(doc_vectors)} documents")
# Out:
# Query: What is machine learning?
# Vector dimensions: 768
# First 5 values: [-0.06847741, -0.040785395, -0.01014158, 0.023063164, 0.0341972]
#
# Embedded 3 documents

# %% [markdown]
# ## 3. Google Gemini Embeddings

# %%
# !uv pip install langchain-google-genai
# !pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in D:\Learning\learning_production_ai\venv\Lib\site-packages (4.3.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-google-genai) (2.16.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-google-genai) (1.5.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.56.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (16.1.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (50.0.0)
# Requirement already satisfied: certifi in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pycparser in D:\Learning\learning_production_ai\venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.4)
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Google Gemini Embeddings
if os.getenv("GOOGLE_API_KEY"):
    from langchain_google_genai import GoogleGenerativeAIEmbeddings
    
    gemini_embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    
    vector = gemini_embeddings.embed_query("Hello world")
    print(f"Gemini vector dimensions: {len(vector)}")
else:
    print("⚠️ Google API key not found. Set GOOGLE_API_KEY in .env")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Gemini vector dimensions: 3072

# %% [markdown]
# ## 4. Similarity Calculation

# %%
import numpy as np

def cosine_similarity(vec1, vec2):
    """Calculate cosine similarity between two vectors"""
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Test similarity
texts = [
    "I love programming",
    "I enjoy coding",
    "The weather is nice"
]

vectors = [embeddings.embed_query(text) for text in texts]

print("Similarity Scores:")
print(f"'{texts[0]}' vs '{texts[1]}': {cosine_similarity(vectors[0], vectors[1]):.4f}")
print(f"'{texts[0]}' vs '{texts[2]}': {cosine_similarity(vectors[0], vectors[2]):.4f}")
print("\nSimilar meanings = Higher similarity score!")
# Out:
# Similarity Scores:
# 'I love programming' vs 'I enjoy coding': 0.8476
# 'I love programming' vs 'The weather is nice': 0.4585
#
# Similar meanings = Higher similarity score!

# %% [markdown]
# ## Summary
#
# ✅ Embeddings convert text to vectors
# ✅ OpenAI text-embedding-3-small: 1536 dimensions
# ✅ Google Gemini: 768 dimensions
# ✅ Cosine similarity measures vector similarity
#
# **Next:** Vector Stores for efficient search!
