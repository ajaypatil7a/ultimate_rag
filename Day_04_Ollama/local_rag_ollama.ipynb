# %% [markdown]
# # Local Offline RAG with Ollama
#
# ## Overview
# This notebook demonstrates building a **completely offline RAG (Retrieval-Augmented Generation)** system using **Ollama** for local LLMs and embeddings.
#
# ### 🚀 Benefits of Local RAG:
# - **100% Offline**: No internet required after setup
# - **Privacy First**: Your documents never leave your machine
# - **No API Costs**: Free to run unlimited queries
# - **Fast**: No network latency
# - **Full Control**: Customize models and parameters
#
# ### 📋 Architecture:
# ```
# PDF Documents → Load → Split → Local Embeddings (Ollama) → ChromaDB
#                                                                   ↓
# User Query → Retrieve Similar Chunks → Local LLM (Ollama) → Answer
# ```
#
# ### 🛠️ Components:
# - **Document Loader**: PyPDFLoader
# - **Text Splitter**: RecursiveCharacterTextSplitter
# - **Embeddings**: Ollama with nomic-embed-text (or embeddinggemma)
# - **Vector Store**: ChromaDB (persistent, local)
# - **LLM**: Ollama with gemma3:1b
# - **Chain**: LangChain Expression Language (LCEL)
#
# ---

# %% [markdown]
# ## 1. Prerequisites & Installation
#
# ### Required Software:
# 1. **Ollama**: Download from https://ollama.ai
# 2. **Python 3.9+**: Recommended 3.11 or 3.13
#
# ### Install Python Packages:

# %%
# !pip install langchain-ollama
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-ollama) (1.5.3)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.25.0)
# Requirement already satisfied: certifi in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.7.0)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama, langchain-ollama
#
#    ---------------------------------------- 0/2 [ollama]
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# Successfully installed langchain-ollama-1.1.0 ollama-0.6.2

# %%
# Install required packages (run this once)
# !pip install langchain langchain-core langchain-community langchain-text-splitters
# !pip install langchain-ollama langchain-chroma chromadb
# !pip install pypdf tiktoken

# Or install from requirements.txt with additional packages:
# !pip install -r requirements.txt
# !pip install langchain-ollama langchain-chroma chromadb
# Out:
# Requirement already satisfied: langchain-ollama in D:\Learning\learning_production_ai\venv\Lib\site-packages (1.1.0)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-ollama) (1.5.3)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.10.15)
# Requirement already satisfied: packaging>=23.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.25.0)
# Requirement already satisfied: certifi in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.4.2)
# Requirement already satisfied: numpy>=1.26.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from langchain-chroma) (2.4.4)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from chromadb) (2.14.2)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.52.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.28.0-cp312-cp312-win_amd64.whl.metadata (5.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from chromadb) (4.70.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.83.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.27.1-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from chromadb) (4.26.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in D:\Learning\learning_production_ai\venv\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.5)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting protobuf>=4.25.8 (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.4.9)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-1.26.0-py3-none-any.whl.metadata (16 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\Learning\learning_production_ai\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.9.0->chromadb)
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting httptools>=0.8.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/23.5 MB 882.6 kB/s eta 0:00:27
#     --------------------------------------- 0.5/23.5 MB 882.6 kB/s eta 0:00:27
#    - -------------------------------------- 0.8/23.5 MB 745.8 kB/s eta 0:00:31
#    - -------------------------------------- 0.8/23.5 MB 745.8 kB/s eta 0:00:31
#    - -------------------------------------- 1.0/23.5 MB 762.8 kB/s eta 0:00:30
#    -- ------------------------------------- 1.3/23.5 MB 838.9 kB/s eta 0:00:27
#    -- ------------------------------------- 1.6/23.5 MB 912.1 kB/s eta 0:00:25
#    --- ------------------------------------ 1.8/23.5 MB 967.9 kB/s eta 0:00:23
#    --- ------------------------------------ 2.1/23.5 MB 1.0 MB/s eta 0:00:22
#    --- ------------------------------------ 2.1/23.5 MB 1.0 MB/s eta 0:00:22
#    ---- ----------------------------------- 2.4/23.5 MB 907.1 kB/s eta 0:00:24
#    ---- ----------------------------------- 2.4/23.5 MB 907.1 kB/s eta 0:00:24
#    ---- ----------------------------------- 2.4/23.5 MB 907.1 kB/s eta 0:00:24
#    ---- ----------------------------------- 2.6/23.5 MB 825.2 kB/s eta 0:00:26
#    ---- ----------------------------------- 2.6/23.5 MB 825.2 kB/s eta 0:00:26
#    ---- ----------------------------------- 2.9/23.5 MB 802.6 kB/s eta 0:00:26
#    ----- ---------------------------------- 3.1/23.5 MB 839.0 kB/s eta 0:00:25
#    ----- ---------------------------------- 3.4/23.5 MB 864.0 kB/s eta 0:00:24
#    ------ --------------------------------- 3.7/23.5 MB 868.9 kB/s eta 0:00:23
#    ------ --------------------------------- 3.9/23.5 MB 879.7 kB/s eta 0:00:23
#    ------- -------------------------------- 4.2/23.5 MB 902.1 kB/s eta 0:00:22
#    ------- -------------------------------- 4.5/23.5 MB 897.8 kB/s eta 0:00:22
#    ------- -------------------------------- 4.5/23.5 MB 897.8 kB/s eta 0:00:22
#    -------- ------------------------------- 4.7/23.5 MB 911.2 kB/s eta 0:00:21
#    -------- ------------------------------- 5.0/23.5 MB 926.3 kB/s eta 0:00:21
#    -------- ------------------------------- 5.2/23.5 MB 940.3 kB/s eta 0:00:20
#    --------- ------------------------------ 5.5/23.5 MB 924.3 kB/s eta 0:00:20
#    --------- ------------------------------ 5.8/23.5 MB 932.1 kB/s eta 0:00:20
#    --------- ------------------------------ 5.8/23.5 MB 932.1 kB/s eta 0:00:20
#    ---------- ----------------------------- 6.0/23.5 MB 925.1 kB/s eta 0:00:19
#    ---------- ----------------------------- 6.0/23.5 MB 925.1 kB/s eta 0:00:19
#    ---------- ----------------------------- 6.3/23.5 MB 901.6 kB/s eta 0:00:20
#    ---------- ----------------------------- 6.3/23.5 MB 901.6 kB/s eta 0:00:20
#    ---------- ----------------------------- 6.3/23.5 MB 901.6 kB/s eta 0:00:20
#    ----------- ---------------------------- 6.8/23.5 MB 898.1 kB/s eta 0:00:19
#    ------------ --------------------------- 7.1/23.5 MB 916.5 kB/s eta 0:00:18
#    ------------ --------------------------- 7.1/23.5 MB 916.5 kB/s eta 0:00:18
#    ------------ --------------------------- 7.6/23.5 MB 928.4 kB/s eta 0:00:18
#    ------------- -------------------------- 7.9/23.5 MB 941.1 kB/s eta 0:00:17
#    -------------- ------------------------- 8.4/23.5 MB 979.4 kB/s eta 0:00:16
#    --------------- ------------------------ 8.9/23.5 MB 1.0 MB/s eta 0:00:15
#    ---------------- ----------------------- 9.4/23.5 MB 1.0 MB/s eta 0:00:14
#    ---------------- ----------------------- 9.7/23.5 MB 1.0 MB/s eta 0:00:14
#    ---------------- ----------------------- 9.7/23.5 MB 1.0 MB/s eta 0:00:14
#    ---------------- ----------------------- 10.0/23.5 MB 1.1 MB/s eta 0:00:13
#    ----------------- ---------------------- 10.5/23.5 MB 1.1 MB/s eta 0:00:13
#    ------------------ --------------------- 11.0/23.5 MB 1.1 MB/s eta 0:00:12
#    ------------------- -------------------- 11.5/23.5 MB 1.1 MB/s eta 0:00:11
#    -------------------- ------------------- 12.3/23.5 MB 1.2 MB/s eta 0:00:10
#    ---------------------- ----------------- 13.1/23.5 MB 1.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 13.6/23.5 MB 1.3 MB/s eta 0:00:08
#    ------------------------ --------------- 14.4/23.5 MB 1.3 MB/s eta 0:00:07
#    ------------------------- -------------- 15.2/23.5 MB 1.4 MB/s eta 0:00:07
#    -------------------------- ------------- 15.7/23.5 MB 1.4 MB/s eta 0:00:06
#    ---------------------------- ----------- 16.5/23.5 MB 1.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 17.3/23.5 MB 1.5 MB/s eta 0:00:05
#    ------------------------------ --------- 17.8/23.5 MB 1.5 MB/s eta 0:00:04
#    ------------------------------- -------- 18.4/23.5 MB 1.5 MB/s eta 0:00:04
#    -------------------------------- ------- 18.9/23.5 MB 1.5 MB/s eta 0:00:04
#    -------------------------------- ------- 19.1/23.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 19.9/23.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.4/23.5 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 20.7/23.5 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.5 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------ --- 21.2/23.5 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------ --- 21.8/23.5 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------- -- 22.0/23.5 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 22.8/23.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  23.3/23.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 23.5/23.5 MB 1.6 MB/s  0:00:14
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading grpcio-1.83.0-cp312-cp312-win_amd64.whl (5.2 MB)
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/5.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/5.2 MB 2.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.3/5.2 MB 2.2 MB/s eta 0:00:02
#    -------------- ------------------------- 1.8/5.2 MB 2.2 MB/s eta 0:00:02
#    ------------------ --------------------- 2.4/5.2 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 3.1/5.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 3.4/5.2 MB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.7/5.2 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 4.2/5.2 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.5/5.2 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 4.7/5.2 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 5.0/5.2 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.0/5.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.2/5.2 MB 1.8 MB/s  0:00:02
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.6 MB 1.7 MB/s eta 0:00:03
#    ------ --------------------------------- 0.8/4.6 MB 1.3 MB/s eta 0:00:03
#    --------- ------------------------------ 1.0/4.6 MB 1.1 MB/s eta 0:00:04
#    ------------- -------------------------- 1.6/4.6 MB 1.5 MB/s eta 0:00:03
#    ------------------ --------------------- 2.1/4.6 MB 1.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.6 MB 1.8 MB/s eta 0:00:02
#    --------------------------- ------------ 3.1/4.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 4.2/4.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 2.1 MB/s  0:00:02
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.28.0-cp312-cp312-win_amd64.whl (13.8 MB)
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.8 MB 2.1 MB/s eta 0:00:07
#    --- ------------------------------------ 1.3/13.8 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/13.8 MB 3.1 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/13.8 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/13.8 MB 2.6 MB/s eta 0:00:05
#    --------- ------------------------------ 3.1/13.8 MB 2.5 MB/s eta 0:00:05
#    --------- ------------------------------ 3.4/13.8 MB 2.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.7/13.8 MB 2.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.9/13.8 MB 2.1 MB/s eta 0:00:05
#    ------------ --------------------------- 4.5/13.8 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.7/13.8 MB 2.1 MB/s eta 0:00:05
#    --------------- ------------------------ 5.2/13.8 MB 2.1 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.5/13.8 MB 2.1 MB/s eta 0:00:04
#    ------------------ --------------------- 6.3/13.8 MB 2.1 MB/s eta 0:00:04
#    ------------------- -------------------- 6.6/13.8 MB 2.2 MB/s eta 0:00:04
#    ------------------- -------------------- 6.8/13.8 MB 2.1 MB/s eta 0:00:04
#    --------------------- ------------------ 7.3/13.8 MB 2.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.6/13.8 MB 2.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.9/13.8 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 8.1/13.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------ --------------- 8.4/13.8 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 8.9/13.8 MB 1.9 MB/s eta 0:00:03
#    -------------------------- ------------- 9.2/13.8 MB 1.9 MB/s eta 0:00:03
#    --------------------------- ------------ 9.4/13.8 MB 1.9 MB/s eta 0:00:03
#    ------------------------------ --------- 10.5/13.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.8/13.8 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.3/13.8 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 13.1/13.8 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.8/13.8 MB 2.3 MB/s  0:00:05
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp312-cp312-win_amd64.whl (35 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 3.0 MB/s  0:00:01
# Downloading huggingface_hub-1.26.0-py3-none-any.whl (780 kB)
#    ---------------------------------------- 0.0/780.4 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/780.4 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 780.4/780.4 kB 3.0 MB/s  0:00:00
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading hf_xet-1.6.0-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 2.6 MB/s eta 0:00:02
#    ------------ --------------------------- 1.3/4.0 MB 2.2 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 2.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.6 MB/s  0:00:01
# Downloading typer-0.27.1-py3-none-any.whl (122 kB)
# Downloading annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.52.1-py3-none-any.whl (79 kB)
# Downloading httptools-0.8.0-cp312-cp312-win_amd64.whl (90 kB)
# Downloading watchfiles-1.2.0-cp312-cp312-win_amd64.whl (288 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, shellingham, pyproject_hooks, pybase64, protobuf, overrides, opentelemetry-api, oauthlib, mmh3, mdurl, importlib-resources, httptools, hf-xet, grpcio, click, bcrypt, annotated-doc, watchfiles, uvicorn, requests-oauthlib, opentelemetry-semantic-conventions, opentelemetry-proto, onnxruntime, markdown-it-py, googleapis-common-protos, build, rich, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-common, kubernetes, huggingface-hub, typer, tokenizers, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
#
#    ----------------------------------------  0/38 [pypika]
#    ----------------------------------------  0/38 [pypika]
#    - --------------------------------------  1/38 [flatbuffers]
#    - --------------------------------------  1/38 [flatbuffers]
#    --- ------------------------------------  3/38 [shellingham]
#    ---- -----------------------------------  4/38 [pyproject_hooks]
#    ----- ----------------------------------  5/38 [pybase64]
#    ----- ----------------------------------  5/38 [pybase64]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------ ---------------------------------  6/38 [protobuf]
#    ------- --------------------------------  7/38 [overrides]
#    -------- -------------------------------  8/38 [opentelemetry-api]
#    -------- -------------------------------  8/38 [opentelemetry-api]
#    -------- -------------------------------  8/38 [opentelemetry-api]
#    -------- -------------------------------  8/38 [opentelemetry-api]
#    -------- -------------------------------  8/38 [opentelemetry-api]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    --------- ------------------------------  9/38 [oauthlib]
#    ----------- ---------------------------- 11/38 [mdurl]
#    ------------ --------------------------- 12/38 [importlib-resources]
#    ------------ --------------------------- 12/38 [importlib-resources]
#    ------------ --------------------------- 12/38 [importlib-resources]
#    ------------ --------------------------- 12/38 [importlib-resources]
#    ------------- -------------------------- 13/38 [httptools]
#    -------------- ------------------------- 14/38 [hf-xet]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    --------------- ------------------------ 15/38 [grpcio]
#    ---------------- ----------------------- 16/38 [click]
#    ---------------- ----------------------- 16/38 [click]
#    ---------------- ----------------------- 16/38 [click]
#    ------------------ --------------------- 18/38 [annotated-doc]
#    -------------------- ------------------- 19/38 [watchfiles]
#    --------------------- ------------------ 20/38 [uvicorn]
#    --------------------- ------------------ 20/38 [uvicorn]
#    --------------------- ------------------ 20/38 [uvicorn]
#    --------------------- ------------------ 20/38 [uvicorn]
#    --------------------- ------------------ 20/38 [uvicorn]
#    --------------------- ------------------ 20/38 [uvicorn]
#    ---------------------- ----------------- 21/38 [requests-oauthlib]
#    ---------------------- ----------------- 21/38 [requests-oauthlib]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------- ------------- 22/38 [opentelemetry-semantic-conventions]
#    ------------------------ --------------- 23/38 [opentelemetry-proto]
#    ------------------------ --------------- 23/38 [opentelemetry-proto]
#    ------------------------ --------------- 23/38 [opentelemetry-proto]
#    ------------------------ --------------- 23/38 [opentelemetry-proto]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    ------------------------- -------------- 24/38 [onnxruntime]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    -------------------------- ------------- 25/38 [markdown-it-py]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    --------------------------- ------------ 26/38 [googleapis-common-protos]
#    ---------------------------- ----------- 27/38 [build]
#    ---------------------------- ----------- 27/38 [build]
#    ---------------------------- ----------- 27/38 [build]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ----------------------------- ---------- 28/38 [rich]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    ------------------------------ --------- 29/38 [opentelemetry-sdk]
#    --------------------- ----- 30/38 [opentelemetry-exporter-otlp-proto-common]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
# ...
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    -------------------------------- ------- 31/38 [kubernetes]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    --------------------------------- ------ 32/38 [huggingface-hub]
#    ---------------------------------- ----- 33/38 [typer]
#    ---------------------------------- ----- 33/38 [typer]
#    ---------------------------------- ----- 33/38 [typer]
#    ---------------------------------- ----- 33/38 [typer]
#    ---------------------------------- ----- 33/38 [typer]
#    ---------------------------------- ----- 33/38 [typer]
#    ----------------------------------- ---- 34/38 [tokenizers]
#    ----------------------------------- ---- 34/38 [tokenizers]
#    -------------------------- -- 35/38 [opentelemetry-exporter-otlp-proto-grpc]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ------------------------------------- -- 36/38 [chromadb]
#    ---------------------------------------- 38/38 [langchain-chroma]
#
# Successfully installed annotated-doc-0.0.5 bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 click-8.4.2 durationpy-0.10 flatbuffers-25.12.19 googleapis-common-protos-1.75.0 grpcio-1.83.0 hf-xet-1.6.0 httptools-0.8.0 huggingface-hub-1.26.0 importlib-resources-7.1.0 kubernetes-36.0.3 langchain-chroma-1.1.0 markdown-it-py-4.2.0 mdurl-0.1.2 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.28.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 protobuf-7.35.1 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-15.0.0 shellingham-1.5.4 tokenizers-0.23.1 typer-0.27.1 uvicorn-0.52.1 watchfiles-1.2.0

# %% [markdown]
# ### Download Ollama Models:
#
# Run these commands in your terminal (if you haven't already):
#
# ```bash
# # Embedding model (choose one or both)
# ollama pull nomic-embed-text    # Recommended: 274 MB
# ollama pull embeddinggemma      # Alternative: 621 MB
#
# # LLM for generation
# ollama pull gemma3:1b          # Small & fast: 815 MB
# ```
#
# **Note**: You already have these models downloaded! ✓

# %% [markdown]
# ## 2. Import Required Libraries

# %%
# Standard library imports
import os
import sys
from pathlib import Path

# LangChain Document Loaders
from langchain_community.document_loaders import PyPDFLoader

# LangChain Text Splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Ollama Integration
from langchain_ollama import OllamaEmbeddings, ChatOllama

# ChromaDB Vector Store
from langchain_chroma import Chroma

# LangChain Core Components
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

print("✓ All imports successful!")
print("✓ Ready for local offline RAG!")
print(f"\nPython version: {sys.version}")
# Out:
# C:\Users\ajayp\AppData\Local\Temp\ipykernel_32576\3011457130.py:7: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# ✓ All imports successful!
# ✓ Ready for local offline RAG!
#
# Python version: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %% [markdown]
# ## 3. Verify Ollama Installation
#
# Let's check that Ollama is running and our models are available.

# %%
# Check Ollama is running and list available models
# !ollama list
# Out:
# NAME                     ID              SIZE      MODIFIED
# gemma3:1b                8648f39daa8f    815 MB    4 seconds ago
# embeddinggemma:latest    85462619ee72    621 MB    2 minutes ago

# %%
# Test Ollama connection with a simple query
print("Testing Ollama connection...\n")

try:
    test_llm = ChatOllama(model="gemma3:1b", temperature=0)
    response = test_llm.invoke("Say 'Hello! I am running locally on your machine!'")
    
    print("✓ Ollama is working!")
    print(f"Response: {response.content}")
    
except Exception as e:
    print(f"✗ Error connecting to Ollama: {e}")
    print("\nMake sure Ollama is running. Try: ollama serve")
# Out:
# Testing Ollama connection...
#
# ✓ Ollama is working!
# Response: Hello! I am running locally on your machine! 😊

# %% [markdown]
# ## 4. Load PDF Documents
#
# Load your PDF documents for the RAG system.

# %%
# ===== CONFIGURATION: Update this path to your PDF file =====
pdf_path = "../attention.pdf"  # Change this to your PDF file path
# =============================================================

# Check if file exists
if not os.path.exists(pdf_path):
    print(f"⚠️  ERROR: File '{pdf_path}' not found!")
    print("Please update the pdf_path variable with your PDF file location.")
else:
    # Load the PDF
    loader = PyPDFLoader(pdf_path)
    documents = loader.load()
    
    # Display information
    print(f"✓ Loaded {len(documents)} pages from '{pdf_path}'")
    print(f"\n--- First Page Preview ---")
    print(f"Content (first 300 chars): {documents[0].page_content[:300]}...")
    print(f"\nMetadata: {documents[0].metadata}")
    print(f"\nTotal characters: {sum(len(doc.page_content) for doc in documents):,}")
# Out:
# ✓ Loaded 15 pages from '../attention.pdf'
#
# --- First Page Preview ---
# Content (first 300 chars): Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# Ashish Vaswani∗
# Google Brain
# avaswani@google.com
# Noam Shazeer∗
# Google Brain
# noam@google.com
# Niki Par...
#
# Metadata: {'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-04-10T21:11:43+00:00', 'author': '', 'keywords': '', 'moddate': '2024-04-10T21:11:43+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../attention.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}
#
# Total characters: 39,597

# %% [markdown]
# ### Optional: Load Multiple PDFs from a Directory

# %%
# Uncomment to load multiple PDFs from a directory

# pdf_directory = "./pdfs"
# all_documents = []

# if os.path.exists(pdf_directory):
#     pdf_files = list(Path(pdf_directory).glob("*.pdf"))
#     print(f"Found {len(pdf_files)} PDF files\n")
    
#     for pdf_file in pdf_files:
#         loader = PyPDFLoader(str(pdf_file))
#         docs = loader.load()
#         all_documents.extend(docs)
#         print(f"  ✓ Loaded {len(docs)} pages from {pdf_file.name}")
    
#     print(f"\nTotal pages loaded: {len(all_documents)}")
#     documents = all_documents  # Use this for the rest of the pipeline

# %% [markdown]
# ## 5. Split Documents into Chunks
#
# Break documents into smaller chunks for better retrieval precision.

# %%
# Initialize text splitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1024,        # Characters per chunk
    chunk_overlap=128,      # Overlap to maintain context
    length_function=len,
    separators=["\n\n", "\n", " ", ""]  # Split on paragraphs, then lines, etc.
)

# Split documents
chunks = text_splitter.split_documents(documents)

# Display results
avg_chunk_size = sum(len(chunk.page_content) for chunk in chunks) / len(chunks)

print(f"✓ Split {len(documents)} documents into {len(chunks)} chunks")
print(f"\nAverage chunk size: {avg_chunk_size:.0f} characters")

# Preview chunks
print(f"\n--- Chunk Examples ---")
for i, chunk in enumerate(chunks[:3]):
    print(f"\nChunk {i+1} (length: {len(chunk.page_content)} chars):")
    print(f"{chunk.page_content[:200]}...")
# Out:
# ✓ Split 15 documents into 49 chunks
#
# Average chunk size: 874 characters
#
# --- Chunk Examples ---
#
# Chunk 1 (length: 986 chars):
# Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# ...
#
# Chunk 2 (length: 944 chars):
# based solely on attention mechanisms, dispensing with recurrence and convolutions
# entirely. Experiments on two machine translation tasks show these models to
# be superior in quality while being more pa...
#
# Chunk 3 (length: 986 chars):
# ∗Equal contribution. Listing order is random. Jakob proposed replacing RNNs with self-attention and started
# the effort to evaluate this idea. Ashish, with Illia, designed and implemented the first Tra...

# %% [markdown]
# ## 6. Create Embeddings (Primary: Nomic-Embed-Text)
#
# ### About Nomic-Embed-Text:
# - **Size**: 274 MB
# - **Dimensions**: 768
# - **Performance**: State-of-the-art for local embeddings
# - **Speed**: Fast inference
# - **License**: Open source (Apache 2.0)

# %%
# Initialize Ollama Embeddings with nomic-embed-text
embeddings = OllamaEmbeddings(
    model="embeddinggemma:latest",
    # base_url="http://localhost:11434"  # Default Ollama URL
)

# Test embeddings
print("Testing embeddinggemma:latest embeddings...\n")
sample_text = "This is a test sentence for embeddings."
sample_embedding = embeddings.embed_query(sample_text)

print(f"✓ Embeddings model: embeddinggemma:latest")
print(f"✓ Embedding dimension: {len(sample_embedding)}")
print(f"✓ Sample embedding (first 10 values): {sample_embedding[:10]}")
print(f"\nℹ️  Each chunk will be converted to a {len(sample_embedding)}-dimensional vector")
print(f"ℹ️  All processing happens locally on your machine!")
# Out:
# Testing embeddinggemma:latest embeddings...
#
# ✓ Embeddings model: embeddinggemma:latest
# ✓ Embedding dimension: 768
# ✓ Sample embedding (first 10 values): [-0.13428985, -0.01961435, 0.052470062, 0.012006142, -0.01723249, 0.051958647, 0.009291739, 0.014571309, -0.011852152, -0.068938494]
#
# ℹ️  Each chunk will be converted to a 768-dimensional vector
# ℹ️  All processing happens locally on your machine!

# %% [markdown]
# ## 7. Alternative: EmbeddingGemma (Optional)
#
# ### About EmbeddingGemma:
# - **Size**: 621 MB (larger than nomic)
# - **Dimensions**: 768
# - **Optimized for**: Google Gemma models
# - **Use case**: Better alignment with Gemma LLMs
#
# **Uncomment the code below to use embeddinggemma instead:**

# %%
# # Alternative: Use embeddinggemma instead
# embeddings = OllamaEmbeddings(
#     model="embeddinggemma:latest"
# )

# # Test embeddings
# print("Testing embeddinggemma embeddings...\n")
# sample_text = "This is a test sentence for embeddings."
# sample_embedding = embeddings.embed_query(sample_text)

# print(f"✓ Embeddings model: embeddinggemma")
# print(f"✓ Embedding dimension: {len(sample_embedding)}")
# print(f"✓ Sample embedding (first 10 values): {sample_embedding[:10]}")

# %% [markdown]
# ## 8. Create ChromaDB Vector Store
#
# ### Why ChromaDB?
# - **Local & Persistent**: Stores vectors on disk
# - **Python 3.13 Compatible**: Works with latest Python
# - **Easy to Use**: Simple API
# - **Open Source**: Free and fully featured
#
# **Note**: This step may take a minute as it processes all chunks.

# %%
# Create ChromaDB vector store
print(f"Creating ChromaDB vector store from {len(chunks)} chunks...")
print("This may take a minute...\n")

# Set persistent directory
persist_directory = "./chroma_db"

# Create vector store
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=persist_directory,
    collection_name="local_rag_collection"
)

print(f"✓ ChromaDB vector store created successfully!")
print(f"✓ Indexed {len(chunks)} document chunks")
print(f"✓ Stored at: {persist_directory}")
print(f"\nℹ️  Vector store persisted to disk - you can reload it later!")
# Out:
# Creating ChromaDB vector store from 49 chunks...
# This may take a minute...
#
# ✓ ChromaDB vector store created successfully!
# ✓ Indexed 49 document chunks
# ✓ Stored at: ./chroma_db
#
# ℹ️  Vector store persisted to disk - you can reload it later!

# %% [markdown]
# ### Load Existing Vector Store (Optional)
#
# If you've already created the vector store, you can load it instead:

# %%
# # Uncomment to load existing vector store
# persist_directory = "./chroma_db"

# vectorstore = Chroma(
#     persist_directory=persist_directory,
#     embedding_function=embeddings,
#     collection_name="local_rag_collection"
# )

# print(f"✓ Loaded existing vector store from '{persist_directory}'")
# print(f"✓ Collection: local_rag_collection")

# %% [markdown]
# ## 9. Create Retriever and Test
#
# The retriever finds the most relevant chunks for a given query.

# %%
# Create retriever
retriever = vectorstore.as_retriever(
    search_type="similarity",    # Use cosine similarity
    search_kwargs={"k": 4}        # Retrieve top 4 most relevant chunks
)

print("✓ Retriever configured successfully")
print(f"  - Search type: similarity")
print(f"  - Number of documents to retrieve (k): 4")

# Test retrieval
test_query = "What is the main topic of this document?"
print(f"\n--- Retriever Test ---")
print(f"Query: '{test_query}'")

retrieved_docs = retriever.invoke(test_query)

print(f"\nRetrieved {len(retrieved_docs)} documents:")
for i, doc in enumerate(retrieved_docs):
    print(f"\nDocument {i+1}:")
    print(f"  Content preview: {doc.page_content[:150]}...")
    print(f"  Source: Page {doc.metadata.get('page', 'N/A')}")
# Out:
# ✓ Retriever configured successfully
#   - Search type: similarity
#   - Number of documents to retrieve (k): 4
#
# --- Retriever Test ---
# Query: 'What is the main topic of this document?'
#
# Retrieved 4 documents:
#
# Document 1:
#   Content preview: Scaled Dot-Product Attention
#  Multi-Head Attention
# Figure 2: (left) Scaled Dot-Product Attention. (right) Multi-Head Attention consists of several
# att...
#   Source: Page 3
#
# Document 2:
#   Content preview: our research.
# †Work performed while at Google Brain.
# ‡Work performed while at Google Research.
# 31st Conference on Neural Information Processing System...
#   Source: Page 0
#
# Document 3:
#   Content preview: df f= 2048.
# 3.4 Embeddings and Softmax
# Similarly to other sequence transduction models, we use learned embeddings to convert the input
# tokens and outp...
#   Source: Page 4
#
# Document 4:
#   Content preview: 1 Introduction
# Recurrent neural networks, long short-term memory [13] and gated recurrent [7] neural networks
# in particular, have been firmly establis...
#   Source: Page 1

# %% [markdown]
# ## 10. Configure Ollama LLM (Gemma3:1b)
#
# ### About Gemma3:1b:
# - **Size**: 815 MB
# - **Parameters**: 1 billion
# - **Speed**: Very fast inference
# - **Quality**: Good for most Q&A tasks
# - **Memory**: Low RAM usage
#
# **Alternatives**: You can also use llama3.2 (2GB) or deepseek-r1 (4.7GB) for better quality.

# %%
# Initialize Ollama LLM
llm = ChatOllama(
    model="gemma3:1b",
    temperature=0,          # Deterministic responses (0 = focused, 1 = creative)
    # num_predict=2000,     # Max tokens to generate
    # top_k=40,             # Top-k sampling
    # top_p=0.9,            # Top-p (nucleus) sampling
)

print("✓ LLM configured successfully")
print(f"  - Model: gemma3:1b (local)")
print(f"  - Temperature: 0 (deterministic)")

# Test LLM
test_response = llm.invoke("Say 'Hello! I am Gemma running locally!'")
print(f"\nLLM Test Response: {test_response.content}")
# Out:
# ✓ LLM configured successfully
#   - Model: gemma3:1b (local)
#   - Temperature: 0 (deterministic)
#
# LLM Test Response: Hello! I am Gemma, running locally! 😊

# %% [markdown]
# ### Try Other Local Models (Optional)

# %%
# # Alternative: Use llama3.2 for better quality
# llm = ChatOllama(
#     model="llama3.2:latest",
#     temperature=0
# )

# # Alternative: Use deepseek-r1 for reasoning tasks
# llm = ChatOllama(
#     model="deepseek-r1:latest",
#     temperature=0
# )

# %% [markdown]
# ## 11. Build RAG Chain (LangChain Expression Language)
#
# Combine retrieval and generation into a single pipeline using LCEL.

# %%
# Define prompt template
system_prompt = (
    "You are a helpful assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer the question. "
    "If you don't know the answer based on the context, say that you don't know. "
    "Keep the answer concise and accurate.\n\n"
    "Context: {context}\n\n"
    "Question: {question}"
)

prompt = ChatPromptTemplate.from_template(system_prompt)

# Helper function to format documents
def format_docs(docs):
    """Format retrieved documents into a single string."""
    return "\n\n".join(doc.page_content for doc in docs)

# Build RAG chain using LCEL
rag_chain = (
    {
        "context": retriever | format_docs,  # Retrieve and format docs
        "question": RunnablePassthrough()      # Pass through the question
    }
    | prompt           # Format with prompt template
    | llm              # Generate answer with local LLM
    | StrOutputParser() # Parse output to string
)

print("✓ RAG chain created successfully using LCEL!")
print("\nRAG Pipeline Flow:")
print("  1. User provides a query")
print("  2. Retriever finds top 4 relevant chunks (local ChromaDB)")
print("  3. Chunks are formatted as context")
print("  4. Context + question formatted with prompt template")
print("  5. Local LLM (gemma3:1b) generates answer")
print("  6. Answer parsed and returned")
print("\n🔒 Everything runs locally on your machine!")
# Out:
# ✓ RAG chain created successfully using LCEL!
#
# RAG Pipeline Flow:
#   1. User provides a query
#   2. Retriever finds top 4 relevant chunks (local ChromaDB)
#   3. Chunks are formatted as context
#   4. Context + question formatted with prompt template
#   5. Local LLM (gemma3:1b) generates answer
#   6. Answer parsed and returned
#
# 🔒 Everything runs locally on your machine!

# %% [markdown]
# ## 12. Test RAG Pipeline with Example Queries
#
# Let's test our complete local RAG system!

# %%
# Example Query 1: General question
query1 = "What is the main topic or contribution of this document?"

print(f"Query: {query1}")
print("\nProcessing locally...\n")

answer = rag_chain.invoke(query1)

print("=" * 80)
print("ANSWER:")
print("=" * 80)
print(answer)
print("\n" + "=" * 80)

# Show source documents
print("\nSOURCE DOCUMENTS USED:")
print("=" * 80)
retrieved_docs = retriever.invoke(query1)
for i, doc in enumerate(retrieved_docs):
    print(f"\nDocument {i+1}:")
    print(f"  Page: {doc.metadata.get('page', 'N/A')}")
    print(f"  Content: {doc.page_content[:200]}...")
    print("-" * 80)
# Out:
# Query: What is the main topic or contribution of this document?
#
# Processing locally...
#
# ================================================================================
# ANSWER:
# ================================================================================
# The document discusses Scaled Dot-Product Attention and its application in sequence modeling and machine translation.
#
# ================================================================================
#
# SOURCE DOCUMENTS USED:
# ================================================================================
#
# Document 1:
#   Page: 0
#   Content: our research.
# †Work performed while at Google Brain.
# ‡Work performed while at Google Research.
# 31st Conference on Neural Information Processing Systems (NIPS 2017), Long Beach, CA, USA.
# arXiv:1706.037...
# --------------------------------------------------------------------------------
#
# Document 2:
#   Page: 3
#   Content: Scaled Dot-Product Attention
#  Multi-Head Attention
# Figure 2: (left) Scaled Dot-Product Attention. (right) Multi-Head Attention consists of several
# attention layers running in parallel.
# of the values, ...
# --------------------------------------------------------------------------------
#
# Document 3:
#   Page: 1
#   Content: 1 Introduction
# Recurrent neural networks, long short-term memory [13] and gated recurrent [7] neural networks
# in particular, have been firmly established as state of the art approaches in sequence mod...
# --------------------------------------------------------------------------------
#
# Document 4:
#   Page: 9
#   Content: learning to align and translate. CoRR, abs/1409.0473, 2014.
# [3] Denny Britz, Anna Goldie, Minh-Thang Luong, and Quoc V . Le. Massive exploration of neural
# machine translation architectures. CoRR, abs/...
# --------------------------------------------------------------------------------

# %%
# Example Query 2: Specific information extraction
query2 = "Can you summarize the key technical contributions or innovations mentioned?"

print(f"Query: {query2}")
print("\nProcessing locally...\n")

answer = rag_chain.invoke(query2)

print("=" * 80)
print("ANSWER:")
print("=" * 80)
print(answer)
print("\n" + "=" * 80)
# Out:
# Query: Can you summarize the key technical contributions or innovations mentioned?
#
# Processing locally...
#
# ================================================================================
# ANSWER:
# ================================================================================
# The provided text discusses several significant advancements in neural network research and development. It highlights Jakob’s replacement of RNNs with self-attention, Ashish's work on Transformer models, Nomi’s focus on scaled dot-product attention, Llion’s efforts to optimize model variants, Lukasz’s contributions to tensor2tensor, Aidan’s work on efficient inference and visualizations, and the research conducted by various individuals at Google Brain, including [16] Łukasz Kaiser and Samy Bengio's work on active memory, [17] Łukasz Kaiser and Ilya Sutskever’s Neural GPUs learn algorithms, [18] Nal Kalchbrenner, Lasse Espe Holt, Karen Simonyan, Aaron van den Oord, Alex Graves, and Ko-ray Kavukcuoglu’s Neural machine translation in linear time, and the contributions of Zhouhan Lin, Minwei Feng, Cicero Nogueira dos Santos, Mo Yu, Bing Xiang, and Bowen Zhou.
#
# ================================================================================

# %%
# Example Query 3: Your custom question
custom_query = "What specific details are mentioned about the methodology or approach?"

print(f"Query: {custom_query}")
print("\nProcessing locally...\n")

answer = rag_chain.invoke(custom_query)

print("=" * 80)
print("ANSWER:")
print("=" * 80)
print(answer)
print("\n" + "=" * 80)
# Out:
# Query: What specific details are mentioned about the methodology or approach?
#
# Processing locally...
#
# ================================================================================
# ANSWER:
# ================================================================================
# The context describes that the authors used a “decomposable attention model” during inference, averaging attention-weighted positions, and that they used “Self-attention” as a successful technique in various tasks.
#
# ================================================================================

# %% [markdown]
# ## 13. Interactive Q&A Session
#
# Ask your own questions to the RAG system!

# %%
# Interactive Q&A
def ask_question(question):
    """Ask a question to the RAG system."""
    print(f"\n{'='*80}")
    print(f"Question: {question}")
    print(f"{'='*80}")
    
    answer = rag_chain.invoke(question)
    
    print(f"\nAnswer: {answer}")
    print(f"{'='*80}\n")
    
    return answer

# Try it out!
# Change the question below to ask anything about your document
my_question = "What are the main findings or results?"
ask_question(my_question)
# Out:
# ================================================================================
# Question: What are the main findings or results?
# ================================================================================
#
# Answer: Here's a concise summary of the key findings from the text:
#
# *   The Transformer architecture was presented as the first sequence transduction model based entirely on attention, replacing recurrent layers.
# *   It outperforms previous models (including RNN-based and convolutional architectures) in both English-to-German and English-to-French translation tasks.
# *   The Transformer achieves state-of-the-art results on WMT 2014 tasks.
# ================================================================================
# "Here's a concise summary of the key findings from the text:\n\n*   The Transformer architecture was presented as the first sequence transduction model based entirely on attention, replacing recurrent layers.\n*   It outperforms previous models (including RNN-based and convolutional architectures) in both English-to-German and English-to-French translation tasks.\n*   The Transformer achieves state-of-the-art results on WMT 2014 tasks."

# %% [markdown]
# ## 14. Bonus: Compare Embedding Models (Optional)
#
# Compare retrieval results between nomic-embed-text and embeddinggemma.

# %%
# # Uncomment to compare embedding models

# print("Comparing embedding models...\n")

# test_query = "What is attention mechanism?"

# # Test with nomic-embed-text
# print("=" * 80)
# print("Using nomic-embed-text:")
# print("=" * 80)
# embeddings_nomic = OllamaEmbeddings(model="nomic-embed-text")
# vectorstore_nomic = Chroma.from_documents(
#     documents=chunks[:10],  # Use first 10 chunks for quick test
#     embedding=embeddings_nomic,
#     collection_name="test_nomic"
# )
# retriever_nomic = vectorstore_nomic.as_retriever(search_kwargs={"k": 2})
# docs_nomic = retriever_nomic.invoke(test_query)

# print(f"\nTop retrieved document:")
# print(f"{docs_nomic[0].page_content[:200]}...\n")

# # Test with embeddinggemma
# print("=" * 80)
# print("Using embeddinggemma:")
# print("=" * 80)
# embeddings_gemma = OllamaEmbeddings(model="embeddinggemma:latest")
# vectorstore_gemma = Chroma.from_documents(
#     documents=chunks[:10],
#     embedding=embeddings_gemma,
#     collection_name="test_gemma"
# )
# retriever_gemma = vectorstore_gemma.as_retriever(search_kwargs={"k": 2})
# docs_gemma = retriever_gemma.invoke(test_query)

# print(f"\nTop retrieved document:")
# print(f"{docs_gemma[0].page_content[:200]}...\n")

# print("=" * 80)
# print("\nℹ️  Both models perform well. Choose based on your preference!")
# print("   - nomic-embed-text: Smaller (274MB), general-purpose")
# print("   - embeddinggemma: Larger (621MB), optimized for Gemma models")

# %% [markdown]
# ## 15. Performance Tips & Next Steps
#
# ### 🚀 Performance Optimization:
# 1. **Chunk Size**: Experiment with different sizes (512, 1024, 2048)
# 2. **Retrieval Count (k)**: Try k=3, 4, 5, 6 based on your needs
# 3. **Model Selection**:
#    - Fast: gemma3:1b
#    - Balanced: llama3.2
#    - Best quality: deepseek-r1
# 4. **Temperature**: 0 for factual, 0.3-0.7 for creative
#
# ### 💾 Persistence:
# - Vector store is saved at `./chroma_db`
# - You can reload it without re-embedding documents
# - Delete the directory to start fresh
#
# ### 🔧 Troubleshooting:
# - **Slow responses**: Use smaller model (gemma3:1b)
# - **Out of memory**: Reduce chunk count or use smaller model
# - **Ollama not found**: Make sure `ollama serve` is running
#
# ### 📚 Next Steps:
# 1. Try different documents and PDFs
# 2. Experiment with other Ollama models
# 3. Add custom preprocessing or post-processing
# 4. Build a simple UI with Gradio or Streamlit
# 5. Compare with cloud-based RAG (OpenAI, etc.)
#
# ### 🎉 Congratulations!
# You now have a fully functional **local, offline RAG system** running on your machine!
#
# ---
#
# **Created with LangChain + Ollama + ChromaDB**
